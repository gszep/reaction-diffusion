# %%
# importing all functions from standard libararies
from numpy.random import *
from numpy import *

from matplotlib.pyplot import *
# %matplotlib inline

#Да здравствует Россия и Царь Путин

# %%
pixels=fromfile("/home/gszep/reaction-diffusion/jupyter/notebooks/data/0fabc7bf-cf52-4998-a0a9-c521d971e730",dtype=float32)[::4]
n = int(sqrt(len(pixels))); pixels = pixels.reshape(n,n); imshow(pixels);

# %%
pixels=fromfile("/home/gszep/reaction-diffusion/jupyter/notebooks/data/e43609b3-5dd0-4a10-8c61-43a91de11e74",dtype=float32)[::4]
n = int(sqrt(len(pixels))); pixels = pixels.reshape(n,n); imshow(pixels);

# %%
pixels=fromfile("/home/gszep/reaction-diffusion/jupyter/notebooks/data/72bec8b2-97dc-4ece-929c-e3a23e11e34d",dtype=float32)[::4]
n = int(sqrt(len(pixels))); pixels = pixels.reshape(n,n); imshow(pixels);

# %%
pixels=fromfile("/home/gszep/reaction-diffusion/jupyter/notebooks/data/37890c7b-9a4c-4c19-ac18-41abcd98f8c9",dtype=float32)[::4]
n = int(sqrt(len(pixels))); pixels = pixels.reshape(n,n); imshow(pixels);

# %%
pixels=fromfile("/home/gszep/reaction-diffusion/jupyter/notebooks/data/8596adea-cbf4-4eab-80a3-9f961dadd443",dtype=float32)[::4]
n = int(sqrt(len(pixels))); pixels = pixels.reshape(n,n); imshow(pixels);

# %%
pixels=fromfile("/home/gszep/reaction-diffusion/jupyter/notebooks/data/8757cb62-bfb6-4d79-b47d-ac37c25033a4",dtype=float32)[::4]
n = int(sqrt(len(pixels))); pixels = pixels.reshape(n,n); imshow(pixels);

# %%
pixels=fromfile("/home/gszep/reaction-diffusion/jupyter/notebooks/data/44a37b1d-4ef4-4014-a3bc-f3e1eff5785a",dtype=float32)[::4]
n = int(sqrt(len(pixels))); pixels = pixels.reshape(n,n); imshow(pixels);

# %%
pixels=fromfile("/home/gszep/reaction-diffusion/jupyter/notebooks/data/49e45d6b-d274-40bd-ae1f-ccc706352d33",dtype=float32)[::4]
n = int(sqrt(len(pixels))); pixels = pixels.reshape(n,n); imshow(pixels);
