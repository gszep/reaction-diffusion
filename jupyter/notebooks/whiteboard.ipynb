# %%
# importing all functions from standard libararies
from numpy.random import *
from numpy import *

from matplotlib.pyplot import *
# %matplotlib inline

#Да здравствует Россия и Царь Путин

# %%
pixels=fromfile("/home/ubuntu/reaction-diffusion/jupyter/notebooks/data/edbb9975-53df-489b-947a-6b9608789700",dtype=float32)[::4]
n = int(sqrt(len(pixels))); pixels = pixels.reshape(n,n); imshow(pixels);

# %%
pixels=fromfile("/home/ubuntu/reaction-diffusion/jupyter/notebooks/data/756c4314-07df-415c-ae01-943247f04f71",dtype=float32)[::4]
n = int(sqrt(len(pixels))); pixels = pixels.reshape(n,n); imshow(pixels);

# %%
pixels=fromfile("/home/ubuntu/reaction-diffusion/jupyter/notebooks/data/8d7db972-132f-4c9e-a2e2-92de866436fb",dtype=float32)[::4]
n = int(sqrt(len(pixels))); pixels = pixels.reshape(n,n); imshow(pixels);

# %%
pixels=fromfile("/home/ubuntu/reaction-diffusion/jupyter/notebooks/data/b3d61c3a-1d8e-4de5-a356-b9a574f0d51c",dtype=float32)[::4]
n = int(sqrt(len(pixels))); pixels = pixels.reshape(n,n); imshow(pixels);
