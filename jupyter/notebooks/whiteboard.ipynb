# %%
# importing all functions from standard libararies
from numpy.random import *
from numpy import *

from matplotlib.pyplot import *
# %matplotlib inline

# %%
pixels=fromfile("/home/ubuntu/reaction-diffusion/jupyter/notebooks/data/089e65c9-9fe9-496e-820e-c41827534277",dtype=float32)[::4]
n = int(sqrt(len(pixels))); pixels = pixels.reshape(n,n); imshow(pixels);

# %%
pixels=fromfile("/home/ubuntu/reaction-diffusion/jupyter/notebooks/data/7e473c43-e603-4739-bf35-acf0ca27a045",dtype=float32)[::4]
n = int(sqrt(len(pixels))); pixels = pixels.reshape(n,n); imshow(pixels);

# %%
pixels=fromfile("/home/ubuntu/reaction-diffusion/jupyter/notebooks/data/7a9c238f-86af-4e15-a3b1-4dfcc7cfc7a4",dtype=float32)[::4]
n = int(sqrt(len(pixels))); pixels = pixels.reshape(n,n); imshow(pixels);

# %%
pixels=fromfile("/home/ubuntu/reaction-diffusion/jupyter/notebooks/data/c048c030-a61b-4d3e-b09e-51c766e7dc3b",dtype=float32)[::4]
n = int(sqrt(len(pixels))); pixels = pixels.reshape(n,n); imshow(pixels);
